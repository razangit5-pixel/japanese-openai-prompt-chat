# %% [markdown]
# # Install Mudules

# %%
# %pip install openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [openai]2m2/3 [openai]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Load the Modules

# %%
import os
from openai import OpenAI

# %% [markdown]
# # Try gpt-4o-mini

# %%
endpoint = "https://razansharaf2001-4044-resource.openai.azure.com/openai/v1/"
deployment_name = "gpt-4o-mini"
api_key = "enter your api key"

client = OpenAI(
    base_url=endpoint,
    api_key=api_key
)

completion = client.chat.completions.create(
    model=deployment_name,
    messages=[
        {
            "role": "user",
            "content": "hello",
        }
    ],
    temperature=0.7,
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='Hello! How can I assist you today?', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None)

# %% [markdown]
# # Instruct the model using a system prompt

# %% [markdown]
# ## Load my prompt from .txt file

# %%
file_path = "../llm/basic/system_prompt.txt"

with open(file_path, 'r', encoding='utf-8') as f:
    system_prompt = f.read()

# %% [markdown]
# ## Azure OpenAI configuration

# %%
endpoint = "https://razansharaf2001-4044-resource.openai.azure.com/openai/v1/"
deployment_name = "gpt-4o-mini"
api_key = "enter your api key"

client = OpenAI(
    base_url=endpoint,
    api_key=api_key
)

# %% [markdown]
# ## Chat completion with loaded prompt

# %%
completion = client.chat.completions.create(
    model=deployment_name,
    messages=[
        {
            "role": "system",
            "content": system_prompt  # Loaded from .txt
        },
        {
            "role": "user",
            "content": "How do I say 'I eat sushi'?",
            "role" : 'assistant' , "content" : "👍 Good question! **私は寿司を食べます** (Watashi wa sushi o tabemasu) ✨"
, "role" :"user" , "content": "this is really hard..."
        }
    ],
    temperature=0.7,
)

print(completion.choices[0].message.content)
# Out:
# 😒 **Hard?** You need to focus on practice! Consistency is key. Keep pushing through! 💪
